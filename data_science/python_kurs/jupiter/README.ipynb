# %% [markdown]
# ## Оглавление
#
# <font color = 'blue'>DATA_STRUCTURE_1</font>
#
#     - Создание Series, DataFrame
#         - из спискаа
#         - из словаря
#         - при помощи функций
#         - из файла
#     - Свойства
#         - тип данных
#         - кол-во элементов
#         - кол-во уникальных элементов
#         - индекс и значения
#         - присвоение / изменине имен
#             - инедкса
#             - столбца
#
# <font color = 'blue'>DATA_STRUCTURE_3</font>
#
#     - Вывод значенией
#         - первые / последние строки
#         - столбцы
#         - строки
#             - по метке
#             - по позиции
#         - поиск скалярного значения
#         - одновременный отбор строк и столбцов
#         - транспонирование
#         - переиндексация
#         - случайная подвыборка
#         - настройки вывода
#
# <font color = 'blue'>DATA_STRUCTURE_3</font>
#
#     - Срезы данных
#         - Series
#         - DataFrame
#     - копирование и ссылки
#
# <font color = 'blue'>DATA_STRUCTURE_4</font>
#
#     - Удаление
#     - POP
#     - drop
#     - фильтрация по условию
#
# <font color = 'blue'>DATA_STRUCTURE_5</font>
#
#     - добавление
#     - выравнивание данных
#     - ортировка
#
# <font color = 'blue'>DATA_STRUCTURE_6</font>
#
#     - Индексы
#     - Операции с индексами
#         - сброс
#         - установка
#         - над множествами
#     - Иерархическая индексация
#     - Типы
#         - Основной тип Index
#         - Int64index и RangeIndex
#         - Float64Index
#
# <font color = 'blue'>DATA_STRUCTURE_7</font>
#
#     - Чистка данных
#     - пропущенные значения
#         - поиск
#         - удаление
#         - заполнение
#             - костантой
#             - прямое и обратное
#             - с помощью индексов
#         - интерполяция пропущенных значений
#     - повторяющиеся значения
#     - замена значений
#         - метод map()
#         - метод replace()
#     - применение функций
#         - к столбцам/строкам
#         - к значениям
#
# <font color = 'blue'>DATA_STRUCTURE_8</font>
#
#     - Математические операции
#
# <font color = 'blue'>DATA_STRUCTURE_9</font>
#
# <font color = 'blue'>DATA_STRUCTURE_10</font>
#
# <font color = 'blue'>DATA_STRUCTURE_11</font>
#
# <font color = 'blue'>DATA_STRUCTURE_12</font>
