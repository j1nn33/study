# %% [markdown]
# ## Оглавление
#
# <font color = 'blue'>1_DATA_STRUCTURE</font>
#
#     - Создание Series, DataFrame
#         - из спискаа
#         - из словаря
#         - при помощи функций
#         - из файла
#     - Свойства
#         - тип данных
#         - кол-во элементов
#         - кол-во уникальных элементов
#         - индекс и значения
#         - присвоение / изменине имен
#             - инедкса
#             - столбца
#
# <font color = 'blue'>2_DATA_STRUCTURE</font>
#
#     - Вывод значенией
#         - первые / последние строки
#         - столбцы
#         - строки
#             - по метке
#             - по позиции
#         - поиск скалярного значения
#         - одновременный отбор строк и столбцов
#         - транспонирование
#         - переиндексация
#         - случайная подвыборка
#         - настройки вывода
#
# <font color = 'blue'>3_DATA_STRUCTURE</font>
#
#     - Срезы данных
#         - Series
#         - DataFrame
#     - копирование и ссылки
#
# <font color = 'blue'>4_DATA_STRUCTURE</font>
#
#     - Удаление
#     - POP
#     - drop
#     - фильтрация по условию
#
# <font color = 'blue'>5_DATA_STRUCTURE</font>
#
#     - добавление
#     - выравнивание данных
#     - ортировка
#
# <font color = 'blue'>6_DATA_STRUCTURE</font>
#
#     - Индексы
#     - Операции с индексами
#         - сброс
#         - установка
#         - над множествами
#     - Иерархическая индексация
#     - Типы
#         - Основной тип Index
#         - Int64index и RangeIndex
#         - Float64Index
#
# <font color = 'blue'>7_DATA_STRUCTURE</font>
#
#     - Чистка данных
#     - пропущенные значения
#         - поиск
#         - удаление
#         - заполнение
#             - костантой
#             - прямое и обратное
#             - с помощью индексов
#         - интерполяция пропущенных значений
#     - повторяющиеся значения
#     - замена значений
#         - метод map()
#         - метод replace()
#     - применение функций
#         - к столбцам/строкам
#         - к значениям
#
# <font color = 'blue'>8_DATA_STRUCTURE</font>
#
#     - Математические операции
#         - сводка статистик
#         - арифметические операции
#         - одномерные статистики
#             - минимум / максимум
#             - среднее значение / медиана / мода
#             - дисперсия / среднеквадратичное отклонение
#             - ковариация / корреляция
#         - преобразование данных
#             - дискретизация и квантилизация
#             - куммулятивные суммы
#             - ранжирование
#             - относительное изменение
#         - оконные функции
#
# <font color = 'blue'>9_DATA_STRUCTURE</font>
#
# <font color = 'blue'>10_DATA_STRUCTURE</font>
#
# <font color = 'blue'>11_DATA_STRUCTURE</font>
#
# <font color = 'blue'>12_DATA_STRUCTURE</font>
